# %%
# Load all the environment variables from ~/.bashrc
# %load_ext autoreload
# %autoreload 2
import os
import sys

import test_data_generator as tdg
import test_data_loader as tdl
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Coordinate Conversions

# %%
tdg.generate_coord_conversions()
data = tdl.load_coord_conversions()

print("epoch:", data["epoch"])

coord_froms = data["coord_froms"]
coord_tos = data["coord_tos"]
cart_from = data["cart_from"]

print("original cartesian:", cart_from)

for i, coord_from in enumerate(coord_froms):
    for j, coord_to in enumerate(coord_tos):
        print(f"coord_from: {coord_from}, coord_to: {coord_to}")
        print(data["cart_to"][i][j])
# Out:
# 29051.00042824074
# epoch: 648518437.0
# original cartesian: [ 5.10250960e+03  6.12301152e+03  6.37813680e+03 -4.74321960e+00
#   7.90536600e-01  5.55337561e+00]
# coord_from: GCRF, coord_to: ITRF
# [ 7.88330214e+03  1.17658222e+03  6.37782918e+03 -2.92920650e+00
#   3.17101546e+00  5.55348676e+00]
# coord_from: GCRF, coord_to: ICRF
# [ 5.10250898e+03  6.12301144e+03  6.37813737e+03 -4.74322014e+00
#   7.90536539e-01  5.55337516e+00]
# coord_from: GCRF, coord_to: MI
# [ 2.77242645e+05  2.91504458e+05  9.10410631e+04 -5.43784974e+00
#   1.40748733e+00  5.84050055e+00]
# coord_from: GCRF, coord_to: PA
# [ 4.08716640e+05  3.47733973e+04 -4.32241517e+04 -1.31524728e+00
#   5.23886413e+00  4.86300556e+00]
