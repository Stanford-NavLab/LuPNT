# %%
import pylupnt as pnt
from pylupnt import pylupnt_pybind as pntpb
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 2
#       1 import pylupnt as pnt
# ----> 2 from pylupnt import pylupnt_pybind as pntpb
#       3 import numpy as np
#       4 import matplotlib.pyplot as plt
#
# ImportError: cannot import name 'pylupnt_pybind' from 'pylupnt' (/Users/keidaiiiyama/Documents/sw_navlab/LuPNT/build/lib/python_package/pylupnt/__init__.py)

# %%
# Test if pylunpnt is installed
print(pnt.__version__)

# print functions of pylupnt
print(dir(pnt))
# Out:
# 0.1
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '__warningregistry__', 'pkg_resources', 'plots', 'utils']
