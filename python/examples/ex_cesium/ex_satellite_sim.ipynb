# %%
import numpy as np
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2
import pylupnt as pnt
# Out:
# [00.00][PyLuPNT] Initializing

# %%
from pylupnt import Simulation
import os

# #print all environment variables
# for key, value in os.environ.items():
#     print(f"{key}: {value}")

print("LUPNT PATH:", os.getenv("LUPNT_PATH"))
print("GMAT PATH:", os.getenv("GMAT_PATH"))
print("CESIUM_TOKEN:", os.getenv("CESIUM_TOKEN"))

# simulation
config_sim = {
    "epoch_start_tai_str": "2025-01-01T00:00:00",
    "time_end": 12 * 3600,
    "output": {
        "dir": "output/example",
    },
    "environments": {},  # Todo: Create a environment for lunar orbits (e.g., ionosphere, etc)
    "agents": {},
}

sim = Simulation(config_sim)
# Out:
# LUPNT PATH: /Users/keidaiiiyama/Documents/sw_navlab/LuPNT-private
# GMAT PATH: /Applications/GMAT_R2022a
# CESIUM_TOKEN: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJqdGkiOiIxM2E3NDM5Ny0zN2U4LTRhMWMtYmY0Ni0yYjkyNDc2NWMwODYiLCJpZCI6MzI0MDMwLCJpYXQiOjE3NTMyMjg5Mjh9.V9pLepAXDBJIeWcplfJxyfLmfo8SBYOXoOCYu7BrpbI
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 23
#      19     "environments": {},  # Todo: Create a environment for lunar orbits (e.g., ionosphere, etc)
#      20     "agents": {},
#      21 }
#      22
# ---> 23 sim = Simulation(config_sim)
#
# File ~/Documents/sw_navlab/LuPNT-private/python/pylupnt/core/simulation.py:34, in Simulation.__init__(self, config)
#      33 def __init__(self, config: pnt.Config):
# ---> 34     from pylupnt.agents.agent import Agent
#      36     self.config = config
#      37     self.name = self.__class__.__name__
#
# ModuleNotFoundError: No module named 'pylupnt.agents'
