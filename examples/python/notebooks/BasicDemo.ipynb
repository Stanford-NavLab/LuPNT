# %% [markdown]
# # Python Module Overview
#
# You can write your documentation in a python notebook. I much prefer writing documentation this way!

# %%
import numpy as np
import pylupnt
print("My version is {}".format(pylupnt.__version__))
# Out:
# My version is 1.0.1

# %% [markdown]
# Now we can use the pylupnt library! Here are the available methods:

# %%
print(dir(pylupnt))
# Out:
# ['VectorDouble', 'VectorInt', 'VectorULongInt', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', 'get_pylupnt_version', 'hello', 'multiply_by_scalar_double', 'multiply_by_scalar_int', 'multiply_by_scalar_size_t', 'pkg_resources']

# %% [markdown]
# Heres an example of multiplying an array

# %%
input_array = pylupnt.VectorDouble([0.1, 1.0, 2.0])
pylupnt.multiply_by_scalar_double(input_array, 2.0)
# Out:
# VectorDouble[0.2, 2, 4]

# %%
input_array = pylupnt.VectorDouble(np.array([0.1, 1.0, 2.0]))
pylupnt.multiply_by_scalar_double(input_array, 2.0)
# Out:
# VectorDouble[0.2, 2, 4]

# %% [markdown]
# Heres an example of returning a string

# %%
pylupnt.hello("Jeremy")
# Out:
# 'Hello Jeremy'
